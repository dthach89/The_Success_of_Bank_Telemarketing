# %%
import pandas as pd
from datetime import datetime as dt

# %%
bank_df = pd.read_csv('Paul_visualization/bank-full_1.csv')
bank_df
# Out:
#        index  age           job   marital  education credit_default  balance  \
# 0          0   58    management   married   tertiary             no     2143
# 1          1   44    technician    single  secondary             no       29
# 2          2   33  entrepreneur   married  secondary             no        2
# 3          3   47   blue-collar   married    unknown             no     1506
# 4          4   33       unknown    single    unknown             no        1
# ...      ...  ...           ...       ...        ...            ...      ...
# 45206  45206   51    technician   married   tertiary             no      825
# 45207  45207   71       retired  divorced    primary             no     1729
# 45208  45208   72       retired   married  secondary             no     5715
# 45209  45209   57   blue-collar   married  secondary             no      668
# 45210  45210   37  entrepreneur   married  secondary             no     2971
#
# ...

# %%
bank_df['month'].describe
# Out:
# <bound method NDFrame.describe of 0             may
# 1             may
# 2             may
# 3             may
# 4             may
#            ...
# 45206    november
# 45207    november
# 45208    november
# 45209    november
# 45210    november
# Name: month, Length: 45211, dtype: object>

# %%
look_up = {'january': '01' , 'febuary': '02' , 'march': '03' , 'april': '04' , 'may': '05',
            'june': '06', 'july': '07' , 'august': '08' , 'september': '09' , 'october': '10' , 'november': '11' , 'december': '12' }

bank_df['month'] = bank_df['month'].apply(lambda x: look_up[x])
bank_df
# Out:
#        index  age           job   marital  education credit_default  balance  \
# 0          0   58    management   married   tertiary             no     2143
# 1          1   44    technician    single  secondary             no       29
# 2          2   33  entrepreneur   married  secondary             no        2
# 3          3   47   blue-collar   married    unknown             no     1506
# 4          4   33       unknown    single    unknown             no        1
# ...      ...  ...           ...       ...        ...            ...      ...
# 45206  45206   51    technician   married   tertiary             no      825
# 45207  45207   71       retired  divorced    primary             no     1729
# 45208  45208   72       retired   married  secondary             no     5715
# 45209  45209   57   blue-collar   married  secondary             no      668
# 45210  45210   37  entrepreneur   married  secondary             no     2971
#
# ...

# %%
bank_df['date'] = pd.to_datetime(bank_df[['day', 'month', 'year']])
bank_df
# Out:
#        index  age           job   marital  education credit_default  balance  \
# 0          0   58    management   married   tertiary             no     2143
# 1          1   44    technician    single  secondary             no       29
# 2          2   33  entrepreneur   married  secondary             no        2
# 3          3   47   blue-collar   married    unknown             no     1506
# 4          4   33       unknown    single    unknown             no        1
# ...      ...  ...           ...       ...        ...            ...      ...
# 45206  45206   51    technician   married   tertiary             no      825
# 45207  45207   71       retired  divorced    primary             no     1729
# 45208  45208   72       retired   married  secondary             no     5715
# 45209  45209   57   blue-collar   married  secondary             no      668
# 45210  45210   37  entrepreneur   married  secondary             no     2971
#
# ...

# %%
bank_df = bank_df.drop(['day', 'month', 'year'], axis=1)
bank_df
# Out:
#        index  age           job   marital  education credit_default  balance  \
# 0          0   58    management   married   tertiary             no     2143
# 1          1   44    technician    single  secondary             no       29
# 2          2   33  entrepreneur   married  secondary             no        2
# 3          3   47   blue-collar   married    unknown             no     1506
# 4          4   33       unknown    single    unknown             no        1
# ...      ...  ...           ...       ...        ...            ...      ...
# 45206  45206   51    technician   married   tertiary             no      825
# 45207  45207   71       retired  divorced    primary             no     1729
# 45208  45208   72       retired   married  secondary             no     5715
# 45209  45209   57   blue-collar   married  secondary             no      668
# 45210  45210   37  entrepreneur   married  secondary             no     2971
#
# ...

# %%
bank_df
# Out:
#        index  age           job   marital  education credit_default  balance  \
# 0          0   58    management   married   tertiary             no     2143
# 1          1   44    technician    single  secondary             no       29
# 2          2   33  entrepreneur   married  secondary             no        2
# 3          3   47   blue-collar   married    unknown             no     1506
# 4          4   33       unknown    single    unknown             no        1
# ...      ...  ...           ...       ...        ...            ...      ...
# 45206  45206   51    technician   married   tertiary             no      825
# 45207  45207   71       retired  divorced    primary             no     1729
# 45208  45208   72       retired   married  secondary             no     5715
# 45209  45209   57   blue-collar   married  secondary             no      668
# 45210  45210   37  entrepreneur   married  secondary             no     2971
#
# ...

# %%
bank_df['weekday'] = bank_df['date'].dt.day_name()
bank_df
# Out:
#        index  age           job   marital  education credit_default  balance  \
# 0          0   58    management   married   tertiary             no     2143
# 1          1   44    technician    single  secondary             no       29
# 2          2   33  entrepreneur   married  secondary             no        2
# 3          3   47   blue-collar   married    unknown             no     1506
# 4          4   33       unknown    single    unknown             no        1
# ...      ...  ...           ...       ...        ...            ...      ...
# 45206  45206   51    technician   married   tertiary             no      825
# 45207  45207   71       retired  divorced    primary             no     1729
# 45208  45208   72       retired   married  secondary             no     5715
# 45209  45209   57   blue-collar   married  secondary             no      668
# 45210  45210   37  entrepreneur   married  secondary             no     2971
#
# ...

# %%
bank_df = bank_df.to_csv('Paul_visualization/bank-full_2.csv')
